# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from datetime import datetime

from elections.scrapers.news_scraper import NewsScraper

# %%
query = "'Luis Montenegro'" # "'mariana mortágua'" # "'Pedro Nuno Santos'"
news_finder = NewsScraper(query, datetime(2024, 2, 1), datetime.now())
news_finder.get_metadata()
print(f"metadata size: {len(news_finder.query_metadata)}")
news_finder.get_article()
news_finder.save_articles()
# Out:
# metadata size: 10

# %%
news = news_finder.load_articles()
news
# Out:
#                                                 title  \
# 0   Campanha a todo o gás e a prometedora entrevis...
# 1   "Estamos mais preparados do que quaisquer outr...
# 2   Luís Montenegro: “Qualquer pessoa tem o direit...
# 3   Luís Montenegro nega “falta de comparência do ...
# 4   Luís Montenegro recusa ter medo de debates pol...
# ..                                                ...
# 89  Já há acordo com as televisões e Montenegro va...
# 90  Montenegro "só tem propostas para lucros dos p...
# 91  Debates com PCP e Livre? "De que tem medo Luís...
# 92  Luís Montenegro promete aumentar salários, pen...
# 93  Não viu o debate entre Luís Montenegro e Maria...
#
#                                           description              pubdate  \
# 0   Campanha a todo o gás e a prometedora entrevis...  2023-12-01T08:00:00
# 1   "Estamos mais preparados do que quaisquer outr...  2023-12-02T08:00:00
# 2   Luís Montenegro: “Qualquer pessoa tem o direit...  2024-02-10T15:30:00
# ...
